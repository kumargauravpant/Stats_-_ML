# %%
import numpy as np

# %%
arr = np.random.randint(0,50,25).reshape(5,5)

# %%
arr
# Out:
# array([[18, 33, 16, 19,  8],
#        [ 4, 16, 48, 33, 34],
#        [ 0, 47, 40, 40, 41],
#        [10, 30, 46, 12, 15],
#        [25, 15, 32, 49, 20]])

# %%
print(arr.shape)
# Out:
# (5, 5)

# %%
print(arr.ndim)
# Out:
# 2

# %%
#3d Array
arr = np.random.randint(0,50,20).reshape(2,5,2)

# %%
arr
# Out:
# array([[[ 6, 32],
#         [13, 19],
#         [48,  9],
#         [36, 37],
#         [ 9, 23]],
#
#        [[38,  8],
#         [11,  6],
#         [16, 34],
#         [17, 41],
#         [26, 21]]])

# %%
arr.shape
# Out:
# (2, 5, 2)

# %%
arr.ndim
# Out:
# 3

# %%
a = np.random.randint(0,20,9).reshape(3,3)

# %%
a
# Out:
# array([[ 5, 15, 12],
#        [17,  2, 14],
#        [ 7, 15,  1]])

# %%
b = np.random.randint(0,20,9).reshape(3,3)

# %%
b
# Out:
# array([[15,  2,  5],
#        [ 6,  1,  5],
#        [ 1,  4,  5]])

# %%
if (a.all()==b.all()):
    print('True')
else:
    print('False')
# Out:
# True

# %%
np.array_equal(a,b)
# Out:
# False

# %%
a+b
# Out:
# array([[20, 17, 17],
#        [23,  3, 19],
#        [ 8, 19,  6]])

# %%
a*b
# Out:
# array([[ 75,  30,  60],
#        [102,   2,  70],
#        [  7,  60,   5]])

# %%
a.dot(b)
# Out:
# array([[177,  73, 160],
#        [281,  92, 165],
#        [196,  33, 115]])

# %%
np.add(a,b)
# Out:
# array([[20, 17, 17],
#        [23,  3, 19],
#        [ 8, 19,  6]])

# %%
A = [[2, 5], [5,8]]
np.dot(A,7)
# Out:
# array([[14, 35],
#        [35, 56]])

# %%
A = np.random.randint(0,20,9).reshape(3,3)
B = np.random.randint(20,50,9).reshape(3,3)

# %%
A
# Out:
# array([[ 8, 14,  2],
#        [12,  5,  3],
#        [15, 17,  0]])

# %%
B
# Out:
# array([[30, 20, 40],
#        [29, 32, 26],
#        [36, 40, 43]])

# %%
# %%timeit
print(A*B)
# Out:
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
#  [348 160  78]
#  [540 680   0]]
# [[240 280  80]
